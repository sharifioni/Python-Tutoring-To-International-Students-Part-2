# %%
def square():
    number=int(input("Enter any Number for a square"))
    print(number**2)
    
square()

# %%
def square(num):
    print(num**2)

    
number=int(input("Enter any Number for a square"))
a=square(number)
print(a)
# Out:
# Enter any Number for a square5
# 25
# None

# %%
def square(num):
    return num**2

    
number=int(input("Enter any Number for a square"))
a=square(number)
print(a)
# Out:
# Enter any Number for a square10
# 100

# %% [markdown]
# Temperature Conversion) Implement a fahrenheit function that returns the
# Fahrenheit equivalent of a Celsius temperature. Use the following formula:
# F = (9 / 5) * C + 32
# Use this function to print a chart showing the Fahrenheit equivalents of all Celsius temperatures in the range 0–100 degrees. Use one digit of precision for the results. Print the
# outputs in a neat tabular format.

# %%
#You have to create a farenheit function
#It'll convert celsius temperature to farenheit
#It'll return temperature in farenheit
#Print all farenheit equivalents of celsius temperatures from 0 to 100 degrees

def farenheit(cel):
    F = (9 / 5) * cel + 32
    print("Celcsius=",cel,"Farenheit=",F)
    
for celsius in range(0,101):
    farenheit(celsius)
# Out:
# Celcsius= 0 Farenheit= 32.0
# Celcsius= 1 Farenheit= 33.8
# Celcsius= 2 Farenheit= 35.6
# Celcsius= 3 Farenheit= 37.4
# Celcsius= 4 Farenheit= 39.2
# Celcsius= 5 Farenheit= 41.0
# Celcsius= 6 Farenheit= 42.8
# Celcsius= 7 Farenheit= 44.6
# Celcsius= 8 Farenheit= 46.4
# Celcsius= 9 Farenheit= 48.2
# Celcsius= 10 Farenheit= 50.0
# Celcsius= 11 Farenheit= 51.8
# Celcsius= 12 Farenheit= 53.6
# Celcsius= 13 Farenheit= 55.400000000000006
# Celcsius= 14 Farenheit= 57.2
# Celcsius= 15 Farenheit= 59.0
# Celcsius= 16 Farenheit= 60.8
# Celcsius= 17 Farenheit= 62.6
# Celcsius= 18 Farenheit= 64.4
# Celcsius= 19 Farenheit= 66.2
# Celcsius= 20 Farenheit= 68.0
# Celcsius= 21 Farenheit= 69.80000000000001
# Celcsius= 22 Farenheit= 71.6
# Celcsius= 23 Farenheit= 73.4
# Celcsius= 24 Farenheit= 75.2
# Celcsius= 25 Farenheit= 77.0
# Celcsius= 26 Farenheit= 78.80000000000001
# Celcsius= 27 Farenheit= 80.6
# Celcsius= 28 Farenheit= 82.4
# Celcsius= 29 Farenheit= 84.2
# Celcsius= 30 Farenheit= 86.0
# ...

# %%
def farenheit(cel):
    F=(9 / 5) * cel + 32
    return F
    
for celsius in range(0,101):
    a=farenheit(celsius)
    print(a)
# Out:
# 32.0
# 33.8
# 35.6
# 37.4
# 39.2
# 41.0
# 42.8
# 44.6
# 46.4
# 48.2
# 50.0
# 51.8
# 53.6
# 55.400000000000006
# 57.2
# 59.0
# 60.8
# 62.6
# 64.4
# 66.2
# 68.0
# 69.80000000000001
# 71.6
# 73.4
# 75.2
# 77.0
# 78.80000000000001
# 80.6
# 82.4
# 84.2
# 86.0
# 87.80000000000001
# 89.6
# 91.4
# 93.2
# 95.0
# 96.8
# 98.60000000000001
# 100.4
# 102.2
# 104.0
# 105.8
# 107.60000000000001
# 109.4
# 111.2
# 113.0
# 114.8
# 116.60000000000001
# 118.4
# 120.2
# 122.0
# 123.8
# 125.60000000000001
# 127.4
# 129.2
# 131.0
# 132.8
# 134.60000000000002
# 136.4
# 138.2
# 140.0
# 141.8
# 143.60000000000002
# 145.4
# 147.2
# 149.0
# 150.8
# 152.60000000000002
# 154.4
# 156.2
# 158.0
# 159.8
# 161.6
# 163.4
# 165.20000000000002
# 167.0
# 168.8
# 170.6
# 172.4
# 174.20000000000002
# 176.0
# 177.8
# 179.6
# 181.4
# 183.20000000000002
# 185.0
# 186.8
# 188.6
# 190.4
# 192.20000000000002
# 194.0
# 195.8
# 197.6
# 199.4
# 201.20000000000002
# 203.0
# 204.8
# 206.6
# 208.4
# 210.20000000000002
# 212.0

# %%
def farenheit(cel):
    F=(9 / 5) * cel + 32
    print(F)
    
for celsius in range(0,101):
    print(farenheit(celsius))
# Out:
# 32.0
# None
# 33.8
# None
# 35.6
# None
# 37.4
# None
# 39.2
# None
# 41.0
# None
# 42.8
# None
# 44.6
# None
# 46.4
# None
# 48.2
# None
# 50.0
# None
# 51.8
# None
# 53.6
# None
# 55.400000000000006
# None
# 57.2
# None
# 59.0
# None
# 60.8
# None
# 62.6
# None
# 64.4
# None
# 66.2
# None
# 68.0
# None
# 69.80000000000001
# None
# 71.6
# None
# 73.4
# None
# 75.2
# None
# 77.0
# None
# 78.80000000000001
# None
# 80.6
# None
# 82.4
# None
# 84.2
# None
# 86.0
# None
# 87.80000000000001
# None
# 89.6
# None
# 91.4
# None
# 93.2
# None
# 95.0
# None
# 96.8
# None
# 98.60000000000001
# None
# 100.4
# None
# 102.2
# None
# 104.0
# None
# 105.8
# None
# 107.60000000000001
# None
# 109.4
# None
# 111.2
# None
# 113.0
# None
# 114.8
# None
# 116.60000000000001
# None
# 118.4
# None
# 120.2
# None
# 122.0
# None
# 123.8
# None
# 125.60000000000001
# None
# 127.4
# None
# 129.2
# None
# 131.0
# None
# 132.8
# None
# 134.60000000000002
# None
# 136.4
# None
# 138.2
# None
# 140.0
# None
# ...

# %%
def farenheit(cel):
    F=(9 / 5) * cel + 32
    print(F)
    
for celsius in range(0,101):
    farenheit(celsius)
# Out:
# 32.0
# 33.8
# 35.6
# 37.4
# 39.2
# 41.0
# 42.8
# 44.6
# 46.4
# 48.2
# 50.0
# 51.8
# 53.6
# 55.400000000000006
# 57.2
# 59.0
# 60.8
# 62.6
# 64.4
# 66.2
# 68.0
# 69.80000000000001
# 71.6
# 73.4
# 75.2
# 77.0
# 78.80000000000001
# 80.6
# 82.4
# 84.2
# 86.0
# 87.80000000000001
# 89.6
# 91.4
# 93.2
# 95.0
# 96.8
# 98.60000000000001
# 100.4
# 102.2
# 104.0
# 105.8
# 107.60000000000001
# 109.4
# 111.2
# 113.0
# 114.8
# 116.60000000000001
# 118.4
# 120.2
# 122.0
# 123.8
# 125.60000000000001
# 127.4
# 129.2
# 131.0
# 132.8
# 134.60000000000002
# 136.4
# 138.2
# 140.0
# 141.8
# 143.60000000000002
# 145.4
# 147.2
# 149.0
# 150.8
# 152.60000000000002
# 154.4
# 156.2
# 158.0
# 159.8
# 161.6
# 163.4
# 165.20000000000002
# 167.0
# 168.8
# 170.6
# 172.4
# 174.20000000000002
# 176.0
# 177.8
# 179.6
# 181.4
# 183.20000000000002
# 185.0
# 186.8
# 188.6
# 190.4
# 192.20000000000002
# 194.0
# 195.8
# 197.6
# 199.4
# 201.20000000000002
# 203.0
# 204.8
# 206.6
# 208.4
# 210.20000000000002
# 212.0
